# %% [markdown]
# ## Audio Waveform With and Without DRED Extension

# %%
import pandas as pd  
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

# %%
input_data = read("/Users/albisht/IETF117-OPUS-APPLICATION/output_30/processing/FEMALE/MIC/F10/mic_F10_si2157.wav.output.wav")
audio = input_data[1]

input_data2 = read("/Users/albisht/IETF117-OPUS-APPLICATION/output_30/processing/FEMALE/MIC/F10/mic_F10_si2157.wav.output.wav.resamp.wav")
audio_resample = input_data2[1]

# input_data3 = read("/Users/albisht/IETF117-OPUS-APPLICATION/output_30_dred/processing/FEMALE/MIC/F01/mic_F02_si673.wav.output.resamp.wav")
# audio_resample_dred = input_data3[1]


plt.plot(audio[0:1024])
plt.plot(audio_resample[0:1024])
# plt.plot(audio_resample_dred[0:1024])
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.show()

# %%
   
# data = pd.read_csv('/Users/albisht/IETF117-OPUS-APPLICATION/output_30/scores_pesq.txt', sep=" ", header=None)
# data
# Out:
#                                                     0         1
# 0   processing/FEMALE/MIC/F03/mic_F03_si842.wav.ou...  1.312666
# 1   processing/FEMALE/MIC/F09/mic_F09_si1981.wav.o...  1.351714
# 2   processing/FEMALE/MIC/F04/mic_F04_sx171.wav.ou...  1.362512
# 3   processing/MALE/MIC/M02/mic_M02_si816.wav.outp...  1.384094
# 4   processing/FEMALE/MIC/F05/mic_F05_sx219.wav.ou...  1.391577
# ..                                                ...       ...
# 95  processing/MALE/MIC/M10/mic_M10_si2342.wav.out...  2.547913
# 96  processing/MALE/MIC/M09/mic_M09_si2068.wav.out...  2.576928
# 97  processing/MALE/MIC/M09/mic_M09_si1967.wav.out...  2.682551
# 98  processing/MALE/MIC/M10/mic_M10_si2258.wav.out...  2.696245
# 99  processing/MALE/MIC/M09/mic_M09_si2076.wav.out...  2.784355
#
# [100 rows x 2 columns]

# %%
data = pd.read_csv('/Users/albisht/IETF117-OPUS-APPLICATION/output_30/stats_pesq.txt', sep=":", header=None)
data
# Out:
#                    0         1
# 0         mean score  1.828776
# 1  bottom mean score  1.449803
# 2     top mean score  2.349781

# %% [markdown]
# ## With DRED

# %%
input_data = read("/Users/albisht/IETF117-OPUS-APPLICATION/output_30_dred/processing/FEMALE/MIC/F10/mic_F10_si2280.wav.output.wav")
audio = input_data[1]

input_data2 = read("/Users/albisht/IETF117-OPUS-APPLICATION/output_30_dred/processing/FEMALE/MIC/F10/mic_F10_si2280.wav.output.wav.resamp.wav")
audio_resample = input_data2[1]

plt.plot(audio[0:1024])
plt.plot(audio_resample[0:1024])
# plt.plot(audio_resample_dred[0:1024])
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.show()

# %%
data = pd.read_csv('/Users/albisht/IETF117-OPUS-APPLICATION/output_30_dred/stats_pesq.txt', sep=":", header=None)
data
# Out:
#                    0         1
# 0         mean score  1.747157
# 1  bottom mean score  1.430956
# 2     top mean score  2.169226
